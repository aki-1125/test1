# %%
import fitbit
import pandas as pd
#import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as mp
import csv
import datetime as dt
CLIENT_ID = "22C77B"
CLIENT_SECRET = "279c90c4b54f444c742e19739c8c74e3"
ACCESS_TOKEN = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyMkM3N0IiLCJzdWIiOiI5NkdHNlkiLCJpc3MiOiJGaXRiaXQiLCJ0eXAiOiJhY2Nlc3NfdG9rZW4iLCJzY29wZXMiOiJyc29jIHJhY3QgcnNldCBybG9jIHJ3ZWkgcmhyIHJwcm8gcm51dCByc2xlIiwiZXhwIjoxNjExNzEwNTc4LCJpYXQiOjE2MTE2ODE3Nzh9.wRzxfLslxkLU3e3OUm9tKQ6dgZWWpBR9t8qVo6kEI04"
REFRESH_TOKEN = "53e0917ea04c852b7f751836e779cd7924d7d5aee9c457ed7856e543892218db"
DATE = "2021-01-21"
authd_client = fitbit.Fitbit(CLIENT_ID,CLIENT_SECRET,access_token=ACCESS_TOKEN,refresh_token=REFRESH_TOKEN)
data_sec = authd_client.intraday_time_series('activities/heart', DATE,detail_level='1sec')
heart_sec = data_sec["activities-heart-intraday"]["dataset"]

heart_df = pd.DataFrame.from_dict(heart_sec)
heart_df.index = pd.to_datetime([DATE + " " + t for t in heart_df.time])

# %%
heart_df["2021-01-21 12"]
# Out:
#                          time  value
# 2021-01-21 12:00:13  12:00:13     69
# 2021-01-21 12:00:18  12:00:18     70
# 2021-01-21 12:00:23  12:00:23     71
# 2021-01-21 12:00:28  12:00:28     70
# 2021-01-21 12:00:33  12:00:33     68
# ...                       ...    ...
# 2021-01-21 12:59:38  12:59:38     78
# 2021-01-21 12:59:43  12:59:43     79
# 2021-01-21 12:59:48  12:59:48     79
# 2021-01-21 12:59:53  12:59:53     80
# 2021-01-21 12:59:58  12:59:58     81
#
# [442 rows x 2 columns]
